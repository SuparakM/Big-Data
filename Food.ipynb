# %%
#Import Python Libraries
import numpy as np
import pandas as pd

# %%
#Read csv file
food = pd.read_csv("mexican.csv")

# %%
#แสดงผลการเรียงลำดับจำนวนที่ขาย (quantity) จากมากไปน้อย
food.sort_values(by = 'quantity', ascending = False, inplace = True)
food.head()
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
# 4152      1660        10                 Bottled Water                NaN
# 3887      1559         8                 Side of Chips                NaN
# 3599      1443         7                 Bottled Water                NaN
# 2441       970         5                 Bottled Water                NaN
#
#      item_price
# 3598    $44.25
# 4152    $15.00
# 3887    $13.52
# 3599    $10.50
# 2441     $7.50

# %%
#แสดงค่าสถิติพื้นฐาน
food.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
#แสดงชื่อ column
food.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#แสดงค่าจำนวนขายที่น้อยที่สุด
food['quantity'].min()
# Out:
# 1

# %%
#แสดงข้อมูลจำนวน 30 แถวแรก โดยเรียงจำนวนยอดขายจากมากไปน้อย
food.sort_values(by = 'quantity', ascending = False, inplace = True)
food.head(30)
# Out:
#       order_id  quantity                            item_name  \
# 3598      1443        15         Chips and Fresh Tomato Salsa
# 4152      1660        10                        Bottled Water
# 3887      1559         8                        Side of Chips
# 3599      1443         7                        Bottled Water
# 2441       970         5                        Bottled Water
# 4489      1786         4                  Chips and Guacamole
# 4490      1786         4                    Canned Soft Drink
# 4491      1786         4                    Canned Soft Drink
# 3602      1443         4                      Chicken Burrito
# 1425       577         4                        Bottled Water
# 1880       759         4                        Bottled Water
# 3973      1592         4                    Canned Soft Drink
# 2235       901         4                          Canned Soda
# 1254       511         4                      Chicken Burrito
# ...

# %%
#แสดง datatype ของตัวแปรที่อ่านข้อมูลเข้ามา
food.dtypes

# %%
#แสดงค่าจำนวนขายที่มากที่สุด
food['quantity'].max()
# Out:
# 15

# %%
#แสดงข้อมูล 5 แถวจากสุดท้าย
food.tail(5)
# Out:
#       order_id  quantity           item_name  \
# 4339      1732         1   Canned Soft Drink
# 4365      1743         1     Chicken Burrito
# 4338      1732         1               Chips
# 4337      1732         1        Chicken Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4339                                             [Coke]     $1.25
# 4365  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75
# 4338                                                NaN     $2.15
# 4337  [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
#แสดง datatype ของ quantity
food['quantity'].dtype
# Out:
# dtype('int64')

# %%
#แสดงค่าเฉลี่ยของจำนวนยอดขายของข้อมูล 20 แถวแรก
food['quantity'].mean()
food.head(20)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 4152      1660        10                 Bottled Water
# 3887      1559         8                 Side of Chips
# 3599      1443         7                 Bottled Water
# 2441       970         5                 Bottled Water
# 1254       511         4               Chicken Burrito
# 2235       901         4                   Canned Soda
# 3973      1592         4             Canned Soft Drink
# 1257       511         4  Chips and Fresh Tomato Salsa
# 1880       759         4                 Bottled Water
# 4489      1786         4           Chips and Guacamole
# 3602      1443         4               Chicken Burrito
# 4491      1786         4             Canned Soft Drink
# 4490      1786         4             Canned Soft Drink
# 1425       577         4                 Bottled Water
# 445        193         3                          Bowl
# ...

# %%
#แสดงจำนวนแถวและคอลัมน์ของข้อมูล
food.shape
# Out:
# (4622, 5)

# %%
#แสดงจำนวนข้อมูลทั้งหมด
food.size
# Out:
# 23110

# %%
#แสดงค่าเฉลี่ยของจำนวนที่ขาย
food['quantity'].mean()
# Out:
# 1.0757247944612722

# %%
#แสดง datatype ของแต่ละ column
food.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#แสดงข้อมูล 10 แถวแรก
food.head(10)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 4152      1660        10                 Bottled Water
# 3887      1559         8                 Side of Chips
# 3599      1443         7                 Bottled Water
# 2441       970         5                 Bottled Water
# 1254       511         4               Chicken Burrito
# 2235       901         4                   Canned Soda
# 3973      1592         4             Canned Soft Drink
# 1257       511         4  Chips and Fresh Tomato Salsa
# 1880       759         4                 Bottled Water
#
#                                      choice_description item_price
# 3598                                                NaN    $44.25
# 4152                                                NaN    $15.00
# 3887                                                NaN    $13.52
# 3599                                                NaN    $10.50
# ...
